# %%
from run import get_rs_data #eigner Code zum Erstellen der Time-Series
import matplotlib.pyplot as plt #Fremder Code zum Darstellen der Time-Series

# %%
rstations = get_rs_data() #Time_series erstellen
station_id = "617104100000"
current_station = rstations[station_id]
# Out:
# 612061790010: step1 finished
# 612061790010: step2 finished
# 612061790010: step3 finished
# 612061790010: step4 finished
# 612061790010: step5 finished
# 612061790010: step6 finished
# 612061790010: step7 finished
# ---------------------------------------------------------------------
# 617102030000: step1 finished
# 617102030000: step2 finished
# 617102030000: step3 finished
# 617102030000: step4 finished
# 617102030000: step5 finished
# 617102030000: step6 finished
# 617102030000: step7 finished
# ---------------------------------------------------------------------
# 617103200000: step1 finished
# 617103200000: step2 finished
# 617103200000: step3 finished
# 617103200000: step4 finished
# 617103200000: step5 finished
# 617103200000: step6 finished
# 617103200000: step7 finished
# ---------------------------------------------------------------------
# 617103380000: step1 finished
# 617103380000: step2 finished
# 617103380000: step3 finished
# 617103380000: step4 finished
# ...

# %%
time = [] #Zeitdaten
temp = [] #Temperaturdaten
data = [] #Metadaten
for index, year in enumerate(current_station.data):
    if not current_station.ann[index] == -9999 and not year.year == 2018:
        time.append(year.year)
        temp.append(current_station.ann[index]/100)

# %%
plt.plot(time, temp)
plt.xlabel("Jahr")
plt.ylabel("Temperatur")
plt.show()
